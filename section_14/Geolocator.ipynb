# %%
import os

os.listdir()
# Out:
# ['supermarkets.csv',
#  'Без названия.ipynb',
#  'getting_started_pandas_110.ipynb',
#  '.~lock.supermarkets.xlsx#',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.json']

# %%
import pandas

df1 = pandas.read_json("supermarkets.json")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_excel("supermarkets.xls")

# %%
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")

# %%
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep = ";")

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = df5.set_index("ID")
df6
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6.set_index("City", inplace=True)
df6
# Out:
#                        Address             State Country          Name  \
# City
# San Francisco     3666 21st St          CA 94114     USA       Madeira
# San Francisco   735 Dolores St          CA 94119     USA   Bready Shop
# San Francisco      332 Hill St  California 94114     USA   Super River
# San Francisco     3995 23rd St          CA 94114     USA    Ben's Shop
# San Francisco  1056 Sanchez St        California     USA       Sanchez
# San Francisco  551 Alvarado St          CA 94114     USA    Richvalley
#
#                Employees
# City
# San Francisco          8
# San Francisco         15
# San Francisco         25
# San Francisco         10
# San Francisco         12
# San Francisco         20

# %%
df6.set_index("State", inplace = True, drop=False)
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees
# State
# CA 94114                  8
# CA 94119                 15
# California 94114         25
# CA 94114                 10
# California               12
# CA 94114                 20

# %%
df6.loc["CA 94119": "California", "State":"Name"]
# Out:
#                              State Country          Name
# State
# CA 94119                  CA 94119     USA   Bready Shop
# California 94114  California 94114     USA   Super River
# CA 94114                  CA 94114     USA    Ben's Shop
# California              California     USA       Sanchez

# %%
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees
# State
# CA 94114                  8
# CA 94119                 15
# California 94114         25
# CA 94114                 10
# California               12
# CA 94114                 20

# %%
df6.iloc[1:5,1:4]
# Out:
#                              State Country          Name
# State
# CA 94119                  CA 94119     USA   Bready Shop
# California 94114  California 94114     USA   Super River
# CA 94114                  CA 94114     USA    Ben's Shop
# California              California     USA       Sanchez

# %%
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees
# State
# CA 94114                  8
# CA 94119                 15
# California 94114         25
# CA 94114                 10
# California               12
# CA 94114                 20

# %%
df6.drop("CA 94114", 0)
# Out:
#                           Address             State Country          Name  \
# State
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# California        1056 Sanchez St        California     USA       Sanchez
#
#                   Employees
# State
# CA 94119                 15
# California 94114         25
# California               12

# %%
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees
# State
# CA 94114                  8
# CA 94119                 15
# California 94114         25
# CA 94114                 10
# California               12
# CA 94114                 20

# %%
df6.drop("Country", 1)
# Out:
#                           Address             State          Name  Employees
# State
# CA 94114             3666 21st St          CA 94114       Madeira          8
# CA 94119           735 Dolores St          CA 94119   Bready Shop         15
# California 94114      332 Hill St  California 94114   Super River         25
# CA 94114             3995 23rd St          CA 94114    Ben's Shop         10
# California        1056 Sanchez St        California       Sanchez         12
# CA 94114          551 Alvarado St          CA 94114    Richvalley         20

# %%
df6.drop(df6.index[1:4], 0)
# Out:
#                     Address       State Country     Name  Employees
# State
# California  1056 Sanchez St  California     USA  Sanchez         12

# %%
df6.drop(df6.columns[1:4], 1)
# Out:
#                           Address  Employees
# State
# CA 94114             3666 21st St          8
# CA 94119           735 Dolores St         15
# California 94114      332 Hill St         25
# CA 94114             3995 23rd St         10
# California        1056 Sanchez St         12
# CA 94114          551 Alvarado St         20

# %%
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees
# State
# CA 94114                  8
# CA 94119                 15
# California 94114         25
# CA 94114                 10
# California               12
# CA 94114                 20

# %%
df6["Continent"] = df6.shape[0]*["North America"]

# %%
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees      Continent
# State
# CA 94114                  8  North America
# CA 94119                 15  North America
# California 94114         25  North America
# CA 94114                 10  North America
# California               12  North America
# CA 94114                 20  North America

# %%
df6.shape[0]
# Out:
# 6

# %%
 We are going to use Nominatim() in the next video. Nominatim() currently has a bug. To fix this problem, whenever you see these lines in the next video:

from geopy.geocoders import Nominatim
nom = Nominatim()
change them to these

from geopy.geocoders import ArcGIS
nom = ArcGIS()
The rest of the code remains the same.
# Out:
#   File "<ipython-input-36-94d828657ea0>", line 1
#     We are going to use Nominatim() in the next video. Nominatim() currently has a bug. To fix this problem, whenever you see these lines in the next video:
#        ^
# SyntaxError: invalid syntax

# %%
from geopy import ArcGIS
nom = ArcGIS()

# %%
df6
# Out:
#                           Address             State Country          Name  \
# State
# CA 94114             3666 21st St          CA 94114     USA       Madeira
# CA 94119           735 Dolores St          CA 94119     USA   Bready Shop
# California 94114      332 Hill St  California 94114     USA   Super River
# CA 94114             3995 23rd St          CA 94114     USA    Ben's Shop
# California        1056 Sanchez St        California     USA       Sanchez
# CA 94114          551 Alvarado St          CA 94114     USA    Richvalley
#
#                   Employees      Continent
# State
# CA 94114                  8  North America
# CA 94119                 15  North America
# California 94114         25  North America
# CA 94114                 10  North America
# California               12  North America
# CA 94114                 20  North America

# %%
data_geo = pandas.read_csv("supermarkets.csv")

# %%
data_geo
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
n = nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
data_geo["Address"] = data_geo["Address"] + ", " + data_geo["City"] + ", " + data_geo["State"] + ", " + data_geo["Country"]
data_geo
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
data_geo["Coordinates"] = data_geo["Address"].apply(nom.geocode)
data_geo.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
data_geo.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
data_geo
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
data_geo["Latitude"] = data_geo["Coordinates"].apply(lambda x: x.latitude if x != None else None)
data_geo
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
help(data_geo.Coordinates[0])
# Out:
# Help on Location in module geopy.location object:
#
# class Location(builtins.object)
#  |  Location(address, point, raw)
#  |
#  |  Contains a parsed geocoder response. Can be iterated over as
#  |  ``(location<String>, (latitude<float>, longitude<Float))``.
#  |  Or one can access the properties ``address``, ``latitude``,
#  |  ``longitude``, or ``raw``. The last
#  |  is a dictionary of the geocoder's response for this item.
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __getitem__(self, index)
#  |      Backwards compatibility with geopy<0.98 tuples.
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, address, point, raw)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  __len__(self)
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
# ...

# %%
help(Location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-fa03c51c2084> in <module>
# ----> 1 help(Location)
#
# NameError: name 'Location' is not defined

# %%
geopy.location.Location?
# Out:
# Object `geopy.location.Location` not found.

# %%
data_geo.Coordinates[0].longitude
# Out:
# -122.42937496976432

# %%
data_geo["Longitude"] = data_geo["Coordinates"].apply(lambda x: x.longitude if x != None else None)
data_geo
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
